# %%
from sklearn.datasets import make_blobs

x,_=make_blobs(n_samples=300, centers=4, cluster_std=1.0, random_state=42)

print(x.shape)
# Out:
# (300, 2)

# %%
import matplotlib.pyplot as plt
plt.scatter(x[:,0],x[:,1])
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %%
from sklearn.cluster import KMeans

model=KMeans(n_clusters=4, random_state=42)
model.fit(x)
labels=model.labels_
print(labels)
# Out:
# [3 3 0 1 3 1 2 1 0 2 0 2 0 0 3 0 3 2 0 0 2 0 1 3 0 3 3 1 1 2 0 2 3 2 3 0 3
#  1 3 1 2 0 3 1 0 0 3 2 3 2 1 3 1 0 1 2 3 2 2 0 3 2 2 0 1 1 1 1 1 0 1 1 3 2
#  0 3 1 1 0 1 0 0 3 0 1 3 3 2 2 2 3 0 3 0 0 3 1 0 3 3 2 2 2 0 0 0 0 0 1 3 2
#  0 0 0 0 2 3 1 3 1 1 1 0 3 1 3 3 0 3 1 2 0 0 0 0 2 2 3 0 1 0 2 1 0 2 2 2 2
#  1 0 0 3 2 1 0 2 1 3 3 2 0 3 1 3 2 3 1 0 0 0 0 0 1 2 2 1 1 2 2 1 3 0 3 2 2
#  3 1 0 2 2 1 1 1 3 2 1 1 2 2 3 0 0 1 2 0 1 1 3 1 0 0 1 1 2 3 1 3 3 0 3 3 1
#  3 1 2 2 3 3 2 2 2 3 0 1 2 1 3 2 3 3 3 1 1 2 3 1 1 1 3 1 3 1 3 2 1 3 2 0 3
#  0 2 0 3 0 1 2 1 2 2 0 0 1 2 2 3 3 1 0 0 2 2 2 2 1 3 2 1 2 2 1 0 1 2 0 3 0
#  2 0 3 3]

# %%
plt.scatter(x[:,0], x[:,1], c=labels)
plt.xlabel("Feature 1")
plt.ylabel("Featre 2")
plt.show()

# %%
inertia=[]

for k in range(1,11):
    model_2=KMeans(n_clusters=k, random_state=42)
    model_2.fit(x)
    inertia.append(model_2.inertia_)

print(inertia)
# Out:
# [19953.76914827803, 9416.214004352274, 2110.4125218953295, 564.9141808210252, 513.0329042790798, 462.0960007878173, 411.3489318727926, 365.35559929959106, 332.0364571015475, 291.5608624106775]

# %%
plt.plot(range(1,11), inertia, marker="o")
plt.xlabel("Number of clusters (K)")
plt.ylabel("Inertia")
plt.title("Elbow Method")
plt.show()

# %%
from sklearn.metrics import silhouette_score

for k in [2, 3, 4, 5, 6]:
    model = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels = model.fit_predict(x)

    score = silhouette_score(x, labels)

    print("K =", k, "Silhouette Score =", score)
# Out:
# K = 2 Silhouette Score = 0.5902182019276141
# K = 3 Silhouette Score = 0.7569108532473462
# K = 4 Silhouette Score = 0.7915830011443039
# K = 5 Silhouette Score = 0.6890369421581084
# K = 6 Silhouette Score = 0.5514127203000643
